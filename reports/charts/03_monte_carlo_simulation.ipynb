# %%
import matplotlib.pyplot as plt
import numpy as np

# Simulate portfolio (using Monte Carlo)
simulations = simulator.simulate_portfolio(weights)

# Plot multiple simulation paths
plt.figure(figsize=(10,6))
for i in range(min(20, len(simulations))):  # Limit to 20 paths for clarity
    plt.plot(simulations[i], color='gray', alpha=0.1)  # Light gray paths
plt.title('Simulated Portfolio Paths')
plt.xlabel('Days')
plt.ylabel('Portfolio Value')
plt.grid(True)

# Save the figure
plt.savefig('reports/charts/simulated_paths.png')
plt.show()
