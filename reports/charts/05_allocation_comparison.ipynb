# %%
# Calculate mean return and standard deviation for each allocation
mean_returns = []
std_devs = []

for allocation, sims in simulations_dict.items():
    mean_returns.append(np.mean(sims))  # Mean return
    std_devs.append(np.std(sims))  # Standard deviation as risk

# Plot Risk vs Return (Efficient Frontier)
plt.figure(figsize=(10, 6))
plt.scatter(std_devs, mean_returns, c='blue', label='Portfolios')
plt.title('Risk vs Return (Efficient Frontier)')
plt.xlabel('Risk (Standard Deviation)')
plt.ylabel('Return (Mean)')
plt.grid(True)
plt.legend()

# Save the figure
plt.savefig('reports/charts/allocation_frontier.png')
plt.show()
