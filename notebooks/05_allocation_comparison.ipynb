# %%
import matplotlib.pyplot as plt

# Assuming 'results_df' is already populated with the allocation comparison data

# Plot Risk vs Return
plt.figure(figsize=(10, 6))

plt.scatter(results_df["VaR"], results_df["Expected Return"])

# Add text labels for each portfolio
for _, row in results_df.iterrows():
    plt.text(row["VaR"], row["Expected Return"], row["Portfolio"])

plt.xlabel("Risk (VaR)")
plt.ylabel("Expected Return")
plt.title("Risk vs Return Tradeoff")

plt.grid(True)

# Save the chart as .png in the reports/charts folder
plt.savefig("reports/charts/allocation_frontier.png", bbox_inches="tight")

# Show the plot
plt.show()
