# %%
# Calculate average returns
mean_return_A = data['Asset_A_return'].mean()
mean_return_B = data['Asset_B_return'].mean()

# Visualize the return model assumptions
plt.plot(data['Asset_A_return'], label="Asset_A")
plt.plot(data['Asset_B_return'], label="Asset_B")
plt.legend()
plt.title("Returns of Assets Over Time")
plt.show()

print(f"Mean return of Asset_A: {mean_return_A}")
print(f"Mean return of Asset_B: {mean_return_B}")
