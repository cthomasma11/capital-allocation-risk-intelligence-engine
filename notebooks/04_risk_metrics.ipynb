# %%
from src.risk_metrics import calculate_var, calculate_cvar, calculate_drawdown

# Calculate risk metrics for the simulated portfolio
var_95 = calculate_var(simulations, alpha=0.05)
cvar_95 = calculate_cvar(simulations, alpha=0.05)
drawdown = calculate_drawdown(simulations)

# Visualize Drawdown
plt.figure(figsize=(10, 6))
plt.plot(drawdown)
plt.title("Maximum Drawdown")
plt.xlabel("Days")
plt.ylabel("Drawdown")

# Save the chart as .png
plt.savefig("reports/charts/drawdown_chart.png", bbox_inches="tight")

plt.show()

# Print the risk metrics
print(f"VaR at 95% confidence: {var_95}")
print(f"CVaR at 95% confidence: {cvar_95}")
print(f"Maximum Drawdown: {drawdown}")
