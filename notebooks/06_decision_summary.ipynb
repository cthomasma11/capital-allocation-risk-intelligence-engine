# %%
print("""
FINAL DECISION SUMMARY

Objective:
Evaluate portfolio allocation strategies under uncertainty using Monte Carlo simulation and downside risk metrics with real market data (Apple and Microsoft).

Key Findings:

1. Conservative Portfolio
- Lowest expected return
- Lowest downside risk (VaR, CVaR)
- Suitable for risk-averse capital preservation

2. Balanced Portfolio
- Moderate expected return
- Highest VaR (worst downside threshold)
- Dominated by other strategies

3. Aggressive Portfolio
- Highest expected return
- Does NOT exhibit the worst VaR or CVaR
- Strong upside with acceptable downside risk

Insight:
The Balanced portfolio is inefficient—it provides lower returns than the Aggressive portfolio while exposing investors to greater downside risk.

Conclusion:
The Aggressive portfolio offers the most attractive risk-return tradeoff, given that it maximizes expected value without proportionally increasing downside risk.

Recommendation:
Allocate capital toward the Aggressive portfolio, while monitoring drawdowns under stressed market conditions.
""")
